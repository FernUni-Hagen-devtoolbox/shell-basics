# %% [markdown]
# ## Shell Basics - Lernpfad: Anfänger:innen - Übung 01

# %% [markdown]
# **Willkommen in Ihrer ersten Shell-Übung!**
#
# Diese Übung läuft in einem **JupyterLab**-Arbeitsbereich. Sie schreiben und lesen die Anleitung hier im Notebook, aber die Befehle führen Sie im **Terminal** von JupyterLab aus.
# - Öffnen Sie links oder oben im JupyterLab-Menü ein Terminal und geben Sie die Befehle dort ein
# - Diese Sitzung wird nur für eine gewisse Dauer (ca. 6h) gespeichert, d.h. wenn Sie die Umgebung später erneut öffnen, wird sie zurückgesetzt sein
#
# *Hinweis:* Wir hosten diese Umgebung mittels MyBinder. Daher heißt Ihr Standardbenutzer hier traditionell `jovyan`. Sie befinden sich nach dem Start immer in Ihrem zugehörigen home-Verzeichnis.

# %% [markdown]
# ### Aufgabe 1 - Wer bin ich und wo bin ich?
#
# Öffnen Sie in JupyterLab ein Terminal und führen Sie dort `whoami` aus. Damit sehen Sie, mit welchem Benutzer Sie aktuell eingeloggt sind.

# %% [markdown]
# ```bash
# whoami
# ```

# %% [markdown]
# Sie befinden sich in Ihrem home-Verzeichnis. Wir werden im späteren Verlauf des Moduls noch mehr über dieses Verzeichnis und seine Eigenschaften lernen.
#
# Bevor wir das Verzeichnis wechseln, schauen wir uns den Inhalt des aktuellen Verzeichnisses im Terminal an. Dazu gibt es den Befehl `ls` (für *list*).

# %% [markdown]
# ```bash
# ls
# ```

# %% [markdown]
# Um das Verzeichnis anschließend zu wechseln, gibt es den Befehl `cd`. Dabei steht `cd` für *change directory*. `cd` nimmt als Argument den Pfad des Ordners, zu dem Sie wechseln wollen. Wechseln Sie nun im Terminal in den `test`-Ordner.

# %% [markdown]
# ```bash
# cd test
# ```

# %% [markdown]
# Überprüfen Sie im Terminal mit `pwd`, ob der Wechsel geklappt hat.

# %% [markdown]
# ```bash
# pwd
# ```

# %% [markdown]
# In der Ausgabe sehen Sie, dass der `test`-Ordner Teil Ihres home-Verzeichnisses ist. Da Sie sich vor dem `cd` Befehl in diesem befunden haben, hat es gereicht für den Wechsel den **relativen Pfad** zu verwenden.
#
# Der Output von `pwd` gibt immer den **absoluten Pfad** aus. Das ist der gesamte Pfad von der Wurzel des Dateisystems aus. Diese Wurzel wird auf Englisch passenderweise **root** genannt und wird durch einen Schrägstrich **/** repräsentiert.
#
# Wechseln Sie im nächsten Schritt im Terminal zum root-Verzeichnis.

# %% [markdown]
# ```bash
# cd /
# ```

# %% [markdown]
# Sie befinden sich jetzt im root-Verzeichnis. Wenn Sie nun zurück in den `test`-Ordner wechseln wollen, können Sie nicht denselben relativen Pfad wie oben verwenden. Sie müssen nun den relativen Pfad von `/` aus nutzen.

# %% [markdown]
# ```bash
# cd home/jovyan/test
# ```

# %% [markdown]
# ```bash
# pwd
# ```

# %% [markdown]
# Dieser relative Pfad unterscheidet sich nur durch den fehlenden Schrägstrich vom absoluten Pfad.
# Da das home-Verzeichnis einer der wichtigsten Orte für einen/eine Nutzer:in ist und dementsprechend häufig verwendet wird, gibt es eine syntaktische Abkürzung dafür, das Tilde-Symbol **~**.
#
# Um zu überprüfen, wofür das Symbol steht, können Sie im Terminal den Befehl `echo` nutzen. `echo` gibt einfach das als Argument auf dem Bildschirm aus, was übergeben wurde. Handelt es sich dabei um Variablen oder andere Platzhalter, werden diese vorher aufgelöst. So auch hier, die Shell wandelt die Tilde vorher in den absoluten Pfad um. Probieren Sie es aus!

# %% [markdown]
# ```bash
# echo ~
# ```

# %% [markdown]
# Wie Sie sehen, ist das Tilde-Symbol ein Platzhalter für den absoluten Pfad des home-Verzeichnisses. Da das Wechseln in dieses Verzeichnis so regelmäßig geschieht, gibt es eine noch einfachere Variante dafür. Sie können einfach den `cd`-Befehl ohne Argument verwenden und gelangen dann zum home-Verzeichnis.
#
# Um in das home-Verzeichnis zu wechseln, haben Sie also immer vier Möglichkeiten:
# - Sie nutzen den relativen Pfad, vom aktuellen Pfad aus
# - Sie nutzen den absoluten Pfad `cd /home/<Benutzer:in>`
# - Sie nutzen das Tilde-Symbol `cd ~`
# - Sie nutzen nur `cd`

# %% [markdown]
# ```bash
# cd /
# ```

# %% [markdown]
# ```bash
# cd
# ```

# %% [markdown]
# ```bash
# pwd
# ```

# %% [markdown]
# Das Tilde-Symbol wird vor allem in solchen Fällen benutzt, in denen Sie in einen Unterordner des home-Verzeichnisses wechseln wollen. Dann können Sie den ersten Teil des absoluten Pfads dadurch ersetzen.
# Gehen Sie nun nochmal zurück in den root-Ordner und wechseln Sie zum `test`-Ordner, der sich in Ihrem home-Verzeichnis befindet. Nutzen Sie dafür den absoluten Pfad mit Tilde-Symbol.

# %% [markdown]
# ```bash
# cd /
# ```

# %% [markdown]
# ```bash
# cd ~/test
# ```

# %% [markdown]
# Neben der Tilde gibt es noch weitere Platzhalter für das relative Navigieren. Wir nutzen wieder `ls` um uns den Inhalt eines Ordners anzusehen. Allerdings reicht der einfache Befehl nicht aus, denn die Platzhalter sind standardmäßig versteckt. Um diese sichtbar zu machen, müssen wir uns das Verzeichnis mit der Option `-a` ansehen. Option `-a` steht für 'all' und listet auch alle versteckten Dateien (und Ordner) auf, die mit einem Punkt beginnen.
#
# Führen Sie `ls -a` aus. Sie werden dort auch einen simplen Punkt **.** und einen Doppelpunkt **..** sehen. Der einzelne Punkt repräsentiert das aktuelle Verzeichnis, in dem Sie sich gerade befinden. Der Doppelpunkt **..** repräsentiert das relative Elternverzeichnis.

# %% [markdown]
# ```bash
# ls -a
# ```

# %% [markdown]
# Wechseln Sie nun zurück in Ihr home-Verzeichnis (das Elternverzeichnis des `test`-Ordners), indem Sie den doppelten Punkt verwenden.

# %% [markdown]
# ```bash
# cd ..
# ```

# %% [markdown]
# ```bash
# pwd
# ```

# %% [markdown]
# Ein weiterer nützlicher Befehl ist `clear`. Damit können Sie jegliche Ausgabe aus dem Terminal entfernen, falls es unübersichtlich wird und Sie neu in der obersten Zeile ansetzen wollen.

# %% [markdown]
# ```bash
# clear
# ```

# %% [markdown]
# ### Aufgabe 2 - Freie Übung
#
# Nun sind Sie an der Reihe! Kombinieren Sie alle bisher gelernten Befehle (`whoami`, `pwd`, `ls`, `cd` und `echo`), um die folgenden Navigationsschritte komplett selbstständig im Terminal durchzuführen.
#
# **Ihre Aufgaben:**
# 1. Wechseln Sie zunächst in das Wurzelverzeichnis (`root`)
# 2. Lassen Sie sich den Inhalt des Wurzelverzeichnisses anzeigen – vergessen Sie nicht, auch die versteckten Dateien (mit dem Punkt) sichtbar zu machen
# 3. Wechseln Sie von dort aus mit einem einzigen Befehl zurück in Ihr `test`-Verzeichnis (Tipp: Verwenden Sie entweder einen absoluten Pfad oder die Tilde)
# 4. Wechseln Sie mit einem relativen Pfad von dort wieder eine Ebene höher in Ihr Home-Verzeichnis
# 5. Lassen Sie sich abschließend zur Überprüfung Ihren aktuellen Pfad auf dem Bildschirm ausgeben, um sicherzugehen, dass Sie wieder im Home-Verzeichnis gelandet sind
#
# **Viel Erfolg!**
